# %%
# !git clone https://github.com/KHiMAeRA05/PMLDL_movie_recommender_system
# Out:
# Cloning into 'PMLDL_movie_recommender_system'...
# remote: Enumerating objects: 106, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 106 (delta 8), reused 0 (delta 0), pack-reused 86
# Receiving objects: 100% (106/106), 5.68 MiB | 16.87 MiB/s, done.
# Resolving deltas: 100% (40/40), done.

# %%
cd '/kaggle/working/PMLDL_movie_recommender_system/benchmark'
# Out:
# /kaggle/working/PMLDL_movie_recommender_system/benchmark

# %%
# %run evaluate.py
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9339  0.9342  0.9400  0.9384  0.9379  0.9369  0.0024
# MAE (testset)     0.7374  0.7377  0.7420  0.7375  0.7402  0.7390  0.0019
# Fit time          1.39    1.65    1.30    1.57    1.55    1.49    0.13
# Test time         0.22    0.22    0.20    0.33    0.20    0.23    0.05
